# %%
import pandas as pd

# %% [markdown]
# # distance bewteen two locations

# %%
from math import sin, cos, sqrt, atan2, radians

# %%
sub_market=pd.read_csv('submarket_3.csv')
top_msa=pd.read_csv('msa_top.csv')

# %%
sub_market['tep']=1
top_msa['tep']=1
df= pd.merge(sub_market,top_msa, on=['tep'])
df.drop('tep', axis=1)
# Out:
#     submarket_city state                            MSA  MSA_population_2019   \
# 0          Orlando    FL  Orlando-Kissimmee-Sanford, FL             2,608,147
# 1          Orlando    FL  Orlando-Kissimmee-Sanford, FL             2,608,147
# 2          Orlando    FL  Orlando-Kissimmee-Sanford, FL             2,608,147
# 3          Orlando    FL  Orlando-Kissimmee-Sanford, FL             2,608,147
# 4          Orlando    FL  Orlando-Kissimmee-Sanford, FL             2,608,147
# ..             ...   ...                            ...                   ...
# 185          Tulsa    OK                      Tulsa, OK               998,626
# 186          Tulsa    OK                      Tulsa, OK               998,626
# 187          Tulsa    OK                      Tulsa, OK               998,626
# 188          Tulsa    OK                      Tulsa, OK               998,626
# 189          Tulsa    OK                      Tulsa, OK               998,626
#
# ...

# %%
df['dist']=1

# %%
R = 6373.0
for i in range(len(df)):
    lat1 = radians(df['lat1'][i])
    lon1 = radians(df['lng1'][i])
    lat2 = radians(df['lat2'][i])
    lon2 = radians(df['lng2'][i])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    df['dist'][i] = R * c

# %%
df2=df.sort_values(['MSA','dist']).drop_duplicates(['submarket_city'],keep='first')

# %%
df2.to_csv('dist_submarket_msa_top.csv')
